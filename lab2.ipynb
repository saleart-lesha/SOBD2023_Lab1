# %% [markdown]
# # 1. Инициализация PySpark фреймворка

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Импорт библиотек Spark SQL и Spark ML

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql import SparkSession

from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler, StringIndexer, VectorIndexer, MinMaxScaler, OneHotEncoder
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import BinaryClassificationEvaluator, RegressionEvaluator
from pyspark.ml.regression import RandomForestRegressor

spark = SparkSession.builder.master("local[*]").getOrCreate()

# %% [markdown]
# Загрузка исходных данных

# %%
dataframe = spark.read.csv('filtered_data/itineraries_fixed.csv', inferSchema=True, header=True, sep=';')
dataframe.limit(5).toPandas()
# Out:
#   startingAirport destinationAirport  isNonStop  isBasicEconomy  isRefundable  \
# 0             ATL                BOS       True           False         False
# 1             ATL                BOS       True           False         False
# 2             ATL                BOS       True           False         False
# 3             ATL                BOS       True           False         False
# 4             ATL                BOS       True           False         False
#
#    baseFare  totalFare  seatsRemaining  totalTravelDistance  travelDuration
# 0    217.67      248.6               9                  947             149
# 1    217.67      248.6               4                  947             150
# 2    217.67      248.6               9                  947             150
# 3    217.67      248.6               8                  947             152
# 4    217.67      248.6               9                  947             154

# %% [markdown]
# # Задача регрессии

# %% [markdown]
# ### Подготовка данных
#
# Выберем подмножество столбцов для использования в качестве признаков и создадим логическое поле метки с именем label со значениями 1 или 0. В качестве метки выбран столбец load_95

# %%
data = dataframe.select(
    "startingAirport", 
    "destinationAirport", 
    "isNonStop", 
    "isBasicEconomy", 
    "isRefundable", 
    "baseFare",
    "totalFare", 
    "seatsRemaining", 
    "totalTravelDistance",
    ((col("travelDuration")).alias("label")))
data.show(10)
# Out:
# +---------------+------------------+---------+--------------+------------+--------+---------+--------------+-------------------+-----+
# |startingAirport|destinationAirport|isNonStop|isBasicEconomy|isRefundable|baseFare|totalFare|seatsRemaining|totalTravelDistance|label|
# +---------------+------------------+---------+--------------+------------+--------+---------+--------------+-------------------+-----+
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             9|                947|  149|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             4|                947|  150|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             9|                947|  150|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             8|                947|  152|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             9|                947|  154|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             7|                947|  158|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             3|                956|  252|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             3|                956|  318|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             7|                956|  332|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             7|                956|  398|
# +---------------+------------------+---------+--------------+------------+--------+---------+--------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## Разделим данные
#
# Используем 70% данных для обучения, а 30% оставим для тестирования. В данных тестирования столбе ц*binary_load_00l переименован  в trueLale*l, поэтому можно использовать его позже для сравнения прогнозируемых меток с известными фактическими значениями.

# %%
splits = data.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1].withColumnRenamed("label", "trueLabel")
train_rows = train.count()
test_rows = test.count()
print("Training Rows:", train_rows, " Testing Rows:", test_rows)
# Out:
# Training Rows: 652729  Testing Rows: 278816

# %% [markdown]
# Задача регрессии (Случайный лес)

# %%
# Создание столбца признаков для задачи регрессии
strIdx = StringIndexer(inputCols=["startingAirport", "destinationAirport"], outputCols=["startingAirport_idx", "destinationAirport_idx"])
oneHotEnc = OneHotEncoder(inputCols=["startingAirport_idx", "destinationAirport_idx"], outputCols=["startingAirport_enc", "destinationAirport_enc"])
catVect = VectorAssembler(inputCols=["startingAirport_enc", "destinationAirport_enc", "isNonStop", "isBasicEconomy", "isRefundable", "seatsRemaining"], outputCol="reg_catFeatures")
catIdx = VectorIndexer(inputCol=catVect.getOutputCol(), outputCol="reg_idxCatFeatures")
numVect = VectorAssembler(inputCols=["baseFare", "totalFare", "totalTravelDistance"], outputCol="reg_numFeatures")
minMax = MinMaxScaler(inputCol=numVect.getOutputCol(), outputCol='reg_normFeatures')
featVect = VectorAssembler(inputCols=["reg_idxCatFeatures", "reg_numFeatures", "reg_normFeatures"], outputCol="reg_features")

# Создание модели RandomForestRegressor
rf = RandomForestRegressor(labelCol="label", featuresCol="reg_features", numTrees=10)

# Создание и выполнение пайплайна для задачи регрессии
reg_pipeline = Pipeline(stages=[strIdx, oneHotEnc, catVect, catIdx, numVect, minMax, featVect, rf])
reg_model = reg_pipeline.fit(train)
reg_prediction = reg_model.transform(test)

# Вывод результатов
reg_prediction.select("reg_features", "prediction", "trueLabel").show(10, truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------+----------------+---------+
# |reg_features                                                                                                                 |prediction      |trueLabel|
# +-----------------------------------------------------------------------------------------------------------------------------+----------------+---------+
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,120.0,152.6,947.0,0.15140136054421768,0.1623849620643076,0.21527234818868907])         |387.318939844366|417      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065]) |387.318939844366|252      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065]) |387.318939844366|318      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065]) |387.318939844366|332      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065]) |387.318939844366|252      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065]) |387.318939844366|332      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065]) |387.318939844366|398      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])|387.318939844366|280      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])|387.318939844366|322      |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])|387.318939844366|324      |
# +-----------------------------------------------------------------------------------------------------------------------------+----------------+---------+
# only showing top 10 rows

# %%
# Расчет метрик для задачи регрессии
reg_evaluator = RegressionEvaluator(labelCol="trueLabel", predictionCol="prediction", metricName="rmse")
rmse = reg_evaluator.evaluate(reg_prediction)
print("RMSE = ", rmse)
# Out:
# RMSE =  109.10754310014411

# %%
# Расчет метрик для задачи регрессии
reg_evaluator = RegressionEvaluator(labelCol="trueLabel", predictionCol="prediction", metricName="r2")
r2 = reg_evaluator.evaluate(reg_prediction)
print("R² = ", r2)
# Out:
# R² =  0.7153895255963252

# %%
data.select(stddev('label')).show()
# Out:
# +------------------+
# |     stddev(label)|
# +------------------+
# |204.51993614793133|
# +------------------+

# %% [markdown]
# CrossValidator разделяет обучающий набор данных на заданное количество складок (фолдов), обучает модель на части данных и оценивает ее на оставшихся данных. Этот процесс повторяется для каждой комбинации гиперпараметров, и выбирается модель с наилучшей средней производительностью на всех фолдах.

# %%
param_grid = (ParamGridBuilder()
              .addGrid(rf.maxDepth, [2, 5, 10])
              .addGrid(rf.numTrees, [5, 10, 20])
              .build())

cv = CrossValidator(estimator=reg_pipeline,
                            estimatorParamMaps=param_grid,
                            evaluator=RegressionEvaluator(),
                            numFolds=3) 

# Обучение и подбор гиперпараметров
cv_model = cv.fit(train)

best_cv_model = cv_model.bestModel

# Оценка производительности на тестовом наборе
cv_prediction = best_cv_model.transform(test)

# %%
reg_evaluator = RegressionEvaluator(labelCol="trueLabel", predictionCol="prediction", metricName="rmse")
rmse = reg_evaluator.evaluate(cv_prediction)
print("RMSE = ", rmse)
# Out:
# RMSE =  100.15816580956987

# %%
# Расчет метрик для задачи регрессии
reg_evaluator = RegressionEvaluator(labelCol="trueLabel", predictionCol="prediction", metricName="r2")
r2 = reg_evaluator.evaluate(cv_prediction)
print("R² = ", r2)
# Out:
# R² =  0.7601641769719019

# %% [markdown]
# # Задача бинарной классификации

# %% [markdown]
# ## Подготовка данных
#
# Выберем подмножество столбцов для использования в качестве признаков и создадим логическое поле метки с именем label со значениями 1 или 0. В частности, *1* для показателей нагрузок более 35 в *load_95* и *0* для нагрузок менее 35.

# %%
data = dataframe.select(
    "startingAirport", 
    "destinationAirport", 
    "isNonStop", 
    "isBasicEconomy", 
    "isRefundable", 
    "baseFare",
    "totalFare", 
    "seatsRemaining", 
    "totalTravelDistance",
    ((col("travelDuration") > 380).cast("Int").alias("label")))
data.show(10)
# Out:
# +---------------+------------------+---------+--------------+------------+--------+---------+--------------+-------------------+-----+
# |startingAirport|destinationAirport|isNonStop|isBasicEconomy|isRefundable|baseFare|totalFare|seatsRemaining|totalTravelDistance|label|
# +---------------+------------------+---------+--------------+------------+--------+---------+--------------+-------------------+-----+
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             9|                947|    0|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             4|                947|    0|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             9|                947|    0|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             8|                947|    0|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             9|                947|    0|
# |            ATL|               BOS|     true|         false|       false|  217.67|    248.6|             7|                947|    0|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             3|                956|    0|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             3|                956|    0|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             7|                956|    0|
# |            ATL|               BOS|    false|         false|       false|  213.02|    251.1|             7|                956|    1|
# +---------------+------------------+---------+--------------+------------+--------+---------+--------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## Разделим данные
#
# Используем 70% данных для обучения, а 30% оставим для тестирования. В данных тестирования столбе ц*binary_load_00l переименован в* trueLablel, поэтому можно использовать его позже для сравнения прогнозируемых меток с известными фактическими значениями.

# %%
splits = data.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1].withColumnRenamed("label", "trueLabel")
train_rows = train.count()
test_rows = test.count()
print("Training Rows:", train_rows, " Testing Rows:", test_rows)
# Out:
# Training Rows: 652305  Testing Rows: 279240

# %% [markdown]
# ## Вычисление отношения между классами

# %%
positive_count = train.filter(col("label") == 1).count()
negative_count = train.filter(col("label") == 0).count()
balance_ratio = positive_count / negative_count
print("Positive to Negative Class Ratio:", balance_ratio)
# Out:
# Positive to Negative Class Ratio: 1.0451061108167508

# %% [markdown]
# Если balance_ratio близко к 1, это свидетельствует о балансе. Если значительно больше или меньше 1, это может указывать на дисбаланс.

# %%
# Создание столбца признаков для задачи регрессии
strIdx = StringIndexer(inputCols=["startingAirport", "destinationAirport"], outputCols=["startingAirport_idx", "destinationAirport_idx"])
oneHotEnc = OneHotEncoder(inputCols=["startingAirport_idx", "destinationAirport_idx"], outputCols=["startingAirport_enc", "destinationAirport_enc"])
catVect = VectorAssembler(inputCols=["startingAirport_enc", "destinationAirport_enc", "isNonStop", "isBasicEconomy", "isRefundable", "seatsRemaining"], outputCol="reg_catFeatures")
catIdx = VectorIndexer(inputCol=catVect.getOutputCol(), outputCol="reg_idxCatFeatures")
numVect = VectorAssembler(inputCols=["baseFare", "totalFare", "totalTravelDistance"], outputCol="reg_numFeatures")
minMax = MinMaxScaler(inputCol=numVect.getOutputCol(), outputCol='reg_normFeatures')
featVect = VectorAssembler(inputCols=["reg_idxCatFeatures", "reg_numFeatures", "reg_normFeatures"], outputCol="features")
lr = LogisticRegression(labelCol="label",featuresCol="features",maxIter=10,regParam=0.3)
pipeline = Pipeline(stages=[strIdx, oneHotEnc, catVect, catIdx, numVect, minMax, featVect, lr])

# %%
pipelineModel = pipeline.fit(train)

# %%
prediction = pipelineModel.transform(test)
predicted = prediction.select("features", "prediction", "trueLabel")
predicted.show(100, truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------+----------+---------+
# |features                                                                                                                            |prediction|trueLabel|
# +------------------------------------------------------------------------------------------------------------------------------------+----------+---------+
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,120.0,152.6,947.0,0.15140136054421768,0.1623849620643076,0.21527234818868907])                |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,161.86,196.1,956.0,0.20835374149659863,0.21730019062527614,0.2176179306750065])        |0.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])              |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,161.86,197.6,1856.0,0.20835374149659863,0.21919381919634404,0.4521761793067501])       |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,161.86,197.6,1462.0,0.20835374149659863,0.21919381919634404,0.34949179046129786])      |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,161.86,197.6,1856.0,0.20835374149659863,0.21919381919634404,0.4521761793067501])       |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,161.86,197.6,947.0,0.20835374149659863,0.21919381919634404,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,161.86,197.6,1462.0,0.20835374149659863,0.21919381919634404,0.34949179046129786])      |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,191.63,235.2,1462.0,0.24885714285714283,0.2666607753777789,0.34949179046129786])       |0.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,200.0,238.6,947.0,0.26024489795918365,0.2709530001388661,0.21527234818868907])                |0.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,200.0,238.6,947.0,0.26024489795918365,0.2709530001388661,0.21527234818868907])                |0.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,202.79,240.1,956.0,0.2640408163265306,0.272846628709934,0.2176179306750065])                  |0.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,202.79,240.1,956.0,0.2640408163265306,0.272846628709934,0.2176179306750065])                  |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,202.79,240.1,956.0,0.2640408163265306,0.272846628709934,0.2176179306750065])           |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,5.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,251.1,956.0,0.2779591836734694,0.2867332382310984,0.2176179306750065])          |0.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,213.02,252.6,1462.0,0.2779591836734694,0.2886268668021663,0.34949179046129786])               |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,213.02,252.6,947.0,0.2779591836734694,0.2886268668021663,0.21527234818868907])         |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,213.02,252.6,947.0,0.2779591836734694,0.2886268668021663,0.21527234818868907])         |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,213.02,252.6,947.0,0.2779591836734694,0.2886268668021663,0.21527234818868907])         |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,213.02,252.6,1462.0,0.2779591836734694,0.2886268668021663,0.34949179046129786])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,213.02,252.6,1462.0,0.2779591836734694,0.2886268668021663,0.34949179046129786])        |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,213.02,252.6,947.0,0.2779591836734694,0.2886268668021663,0.21527234818868907])         |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,213.02,252.6,947.0,0.2779591836734694,0.2886268668021663,0.21527234818868907])         |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,213.02,252.6,1462.0,0.2779591836734694,0.2886268668021663,0.34949179046129786])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,213.02,252.6,1856.0,0.2779591836734694,0.2886268668021663,0.4521761793067501])         |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,5.0,213.02,252.6,1462.0,0.2779591836734694,0.2886268668021663,0.34949179046129786])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,252.6,1462.0,0.2779591836734694,0.2886268668021663,0.34949179046129786])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,252.6,1856.0,0.2779591836734694,0.2886268668021663,0.4521761793067501])         |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,252.6,1856.0,0.2779591836734694,0.2886268668021663,0.4521761793067501])         |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,213.02,252.6,1856.0,0.2779591836734694,0.2886268668021663,0.4521761793067501])         |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,213.02,252.6,947.0,0.2779591836734694,0.2886268668021663,0.21527234818868907])         |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,225.12,271.2,947.0,0.294421768707483,0.312107861083408,0.21527234818868907])           |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,258.6,300.1,956.0,0.33997278911564627,0.3485917715526492,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,258.6,300.1,956.0,0.33997278911564627,0.3485917715526492,0.2176179306750065])          |0.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,258.6,301.6,947.0,0.33997278911564627,0.35048540012371704,0.21527234818868907])               |0.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,258.6,301.6,947.0,0.33997278911564627,0.35048540012371704,0.21527234818868907])               |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,258.6,301.6,947.0,0.33997278911564627,0.35048540012371704,0.21527234818868907])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,258.6,301.6,947.0,0.33997278911564627,0.35048540012371704,0.21527234818868907])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,258.6,301.6,947.0,0.33997278911564627,0.35048540012371704,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,260.47,302.11,956.0,0.3425170068027211,0.35112923383788014,0.2176179306750065])               |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,262.32,311.19,1118.0,0.34503401360544217,0.36259199878807774,0.2598384154287203])      |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,262.32,311.19,1118.0,0.34503401360544217,0.36259199878807774,0.2598384154287203])      |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,277.21,327.2,947.0,0.36529251700680265,0.3828033277366089,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,277.21,327.2,947.0,0.36529251700680265,0.3828033277366089,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,305.12,357.2,947.0,0.40326530612244893,0.4206758991579665,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,319.07,372.2,1023.0,0.4222448979591836,0.4396121848686453,0.23507948918425853])               |0.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,320.93,367.1,956.0,0.42477551020408155,0.4331738477270145,0.2176179306750065])                |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,320.93,368.6,947.0,0.42477551020408155,0.43506747629808235,0.21527234818868907])       |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,337.67,392.2,947.0,0.4475510204081632,0.46486056581621704,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,342.33,391.61,947.0,0.45389115646258493,0.46411573857826366,0.21527234818868907])      |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,360.93,417.2,947.0,0.47919727891156455,0.4964210420006817,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,3.0,366.51,417.6,947.0,0.48678911564625843,0.4969260096196331,0.21527234818868907])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,366.51,417.6,947.0,0.48678911564625843,0.4969260096196331,0.21527234818868907])        |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,366.51,417.6,947.0,0.48678911564625843,0.4969260096196331,0.21527234818868907])        |0.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,370.23,421.6,947.0,0.4918503401360544,0.5019756858091474,0.21527234818868907])         |0.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,374.88,432.2,947.0,0.49817687074829925,0.5153573277113606,0.21527234818868907])        |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,386.05,438.6,947.0,0.5133741496598639,0.5234368096145835,0.21527234818868907])                |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,386.05,438.6,947.0,0.5133741496598639,0.5234368096145835,0.21527234818868907])         |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,395.35,448.6,947.0,0.5260272108843537,0.5360610000883693,0.21527234818868907])         |1.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,398.14,457.2,947.0,0.5298231292517006,0.5469178038958252,0.21527234818868907])                |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,398.14,457.2,947.0,0.5298231292517006,0.5469178038958252,0.21527234818868907])                |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,416.75,471.61,947.0,0.555142857142857,0.5651092623685506,0.21527234818868907])                |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,416.75,471.61,947.0,0.555142857142857,0.5651092623685506,0.21527234818868907])         |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,417.67,482.7,1106.0,0.5563945578231292,0.5791094896039791,0.2567109721136304])         |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,453.96,511.61,947.0,0.605768707482993,0.615606024263694,0.21527234818868907])                 |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,4.0,460.47,518.61,947.0,0.6146258503401361,0.6244429575953442,0.21527234818868907])        |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,472.56,537.2,1462.0,0.6310748299319727,0.6479113276861121,0.34949179046129786])        |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,2.0,486.51,545.1,956.0,0.6500544217687074,0.657884438160403,0.2176179306750065])           |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,5.0,491.17,551.61,947.0,0.6563945578231292,0.6661027861588376,0.21527234818868907])        |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,1.0,528.37,597.2,1250.0,0.7070068027210884,0.7236564705288273,0.2942402918947094])         |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,8.0,546.98,617.2,947.0,0.7323265306122448,0.7489048514763991,0.21527234818868907])         |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,5.0,565.58,631.6,947.0,0.7576326530612244,0.7670836857586507,0.21527234818868907])         |1.0       |0        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,572.09,638.6,1462.0,0.7664897959183673,0.7759206190903009,0.34949179046129786])               |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,575.82,647.11,1106.0,0.7715646258503401,0.7866638051834925,0.2567109721136304])               |1.0       |1        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,6.0,598.14,666.6,947.0,0.8019319727891155,0.8112683524169012,0.21527234818868907])         |1.0       |0        |
# |(40,[8,18,33,34,35,36,37,38,39],[1.0,1.0,5.0,621.4,697.21,1088.0,0.8335782312925168,0.8499109994571598,0.2520198071409956])         |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,649.3,726.1,947.0,0.8715374149659862,0.8863822857359271,0.21527234818868907])                 |1.0       |1        |
# |(40,[8,18,34,35,36,37,38,39],[1.0,1.0,649.3,731.7,947.0,0.8715374149659862,0.8934518324012473,0.21527234818868907])                 |1.0       |1        |
# |(40,[8,18,31,33,34,35,36,37,38,39],[1.0,1.0,1.0,8.0,188.83,232.19,947.0,0.24504761904761904,0.2628608940451693,0.21527234818868907])|0.0       |1        |
# |(40,[8,18,31,33,34,35,36,37,38,39],[1.0,1.0,1.0,8.0,230.69,277.19,947.0,0.302,0.31966975117720575,0.21527234818868907])             |0.0       |1        |
# +------------------------------------------------------------------------------------------------------------------------------------+----------+---------+
# only showing top 100 rows

# %%
tp = float(predicted.filter("prediction == 1.0 AND truelabel == 1").count())
fp = float(predicted.filter("prediction == 1.0 AND truelabel == 0").count())
tn = float(predicted.filter("prediction == 0.0 AND truelabel == 0").count())
fn = float(predicted.filter("prediction == 0.0 AND truelabel == 1").count())
pr = tp / (tp + fp)
re = tp / (tp + fn)
metrics = spark.createDataFrame([
 ("TP", tp),
 ("FP", fp),
 ("TN", tn),
 ("FN", fn),
 ("Precision", pr),
 ("Recall", re),
 ("F1", 2*pr*re/(re+pr))],["metric", "value"])
metrics.show()
# Out:
# +---------+------------------+
# |   metric|             value|
# +---------+------------------+
# |       TP|          118221.0|
# |       FP|           28846.0|
# |       TN|          107879.0|
# |       FN|           24294.0|
# |Precision|0.8038581054893348|
# |   Recall|0.8295337332912325|
# |       F1|0.8164941191096132|
# +---------+------------------+

# %%
evaluator = BinaryClassificationEvaluator(labelCol="trueLabel", rawPredictionCol="rawPrediction", metricName="areaUnderROC")
aur = evaluator.evaluate(prediction)
print ("AUR = ", aur)
# Out:
# AUR =  0.9143883250778739

# %% [markdown]
# ## Подбор гиперпараметров

# %%
paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.3, 0.1])
             .addGrid(lr.maxIter, [10, 5])
             .addGrid(lr.threshold,[0.4, 0.3])
             .build())

cv = CrossValidator(estimator=pipeline, 
                    evaluator=BinaryClassificationEvaluator(), 
                    estimatorParamMaps=paramGrid, 
                    numFolds=2)

model = cv.fit(train)

# %%
newPrediction = model.transform(test)
newPredicted = prediction.select("features", "prediction", "trueLabel")
newPredicted.show()
# Out:
# +--------------------+----------+---------+
# |            features|prediction|trueLabel|
# +--------------------+----------+---------+
# |(40,[8,18,34,35,3...|       0.0|        1|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,34,35,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        1|
# |(40,[8,18,33,34,3...|       1.0|        1|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       1.0|        1|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        0|
# |(40,[8,18,33,34,3...|       0.0|        1|
# +--------------------+----------+---------+
# only showing top 20 rows

# %%
# Recalculate confusion matrix
tp2 = float(newPrediction.filter("prediction == 1.0 AND truelabel == 1").count())
fp2 = float(newPrediction.filter("prediction == 1.0 AND truelabel == 0").count())
tn2 = float(newPrediction.filter("prediction == 0.0 AND truelabel == 0").count())
fn2 = float(newPrediction.filter("prediction == 0.0 AND truelabel == 1").count())
pr2 = tp2 / (tp2 + fp2)
re2 = tp2 / (tp2 + fn2)
metrics2 = spark.createDataFrame([
 ("TP", tp2),
 ("FP", fp2),
 ("TN", tn2),
 ("FN", fn2),
 ("Precision", pr2),
 ("Recall", re2),
 ("F1", 2*pr2*re2/(re2+pr2))],["metric", "value"])
metrics2.show()
# Out:
# +---------+------------------+
# |   metric|             value|
# +---------+------------------+
# |       TP|          141674.0|
# |       FP|           64399.0|
# |       TN|           72326.0|
# |       FN|             841.0|
# |Precision|0.6874942374789517|
# |   Recall|0.9940988667859524|
# |       F1|0.8128449631083112|
# +---------+------------------+

# %%
# Recalculate the Area Under ROC
evaluator2 = BinaryClassificationEvaluator(labelCol="trueLabel", rawPredictionCol="prediction", metricName="areaUnderROC")
aur2 = evaluator.evaluate(prediction)
print("AUR2 = ", aur2)
# Out:
# AUR2 =  0.914386392883987
